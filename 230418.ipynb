# %%
#https://school.programmers.co.kr/learn/courses/30/lessons/150370#qna
#고객의 약관 동의를 얻어서 수집된 1~n번으로 분류되는 개인정보 n개가 있습니다. 
#약관 종류는 여러 가지 있으며 각 약관마다 개인정보 보관 유효기간이 정해져 있습니다. 
#당신은 각 개인정보가 어떤 약관으로 수집됐는지 알고 있습니다. 
#수집된 개인정보는 유효기간 전까지만 보관 가능하며, 유효기간이 지났다면 반드시 파기해야 합니다.

#예를 들어, A라는 약관의 유효기간이 12 달이고, 2021년 1월 5일에 수집된 개인정보가 A약관으로 수집되었다면 
#해당 개인정보는 2022년 1월 4일까지 보관 가능하며 2022년 1월 5일부터 파기해야 할 개인정보입니다.
#당신은 오늘 날짜로 파기해야 할 개인정보 번호들을 구하려 합니다.

#모든 달은 28일까지 있다고 가정합니다.

def solution(today, terms, privacies):
    answer = []
    today_copy = today
    today = today.split('.') #오늘 연,월 일 나누기
    today_year = int(today[0])
    today_month = int(today[1])
    today_date = int(today[2])
    #print(today_year,today_month,today_date)

    term_unit = {} #계약 사전
    for term in terms:
        term = term.split(' ')
        term_unit[term[0]] = int(term[1]) #계약 타입 : 기간 

    for i, privacie in enumerate(privacies): #계약의 순차 순환 
        privacie = privacie.split(' ') #계약 시작일 / 계약 별 기간으로 분리 
        time_copy = privacie[0]
        time = privacie[0].split('.')
        deadline =term_unit[privacie[1]]
        #계약 시작일로부터 지난 월 수 계산 
        year_term4date = (today_year - int(time[0])) * 12 * 28 #오늘년도 - 계약시작년도 * 12개월 * 28일 
        month_term4date = (today_month - int(time[1])) * 28 #(오늘 달 - 계약시작 달) * 28일(음수면 년수에서 빠질 예정)
        date_term = today_date - int(time[2]) #일 수 차 계산
        #print(int(time[0]),int(time[1]),int(time[2]))

        time_term = year_term4date + month_term4date + date_term #지난 일 수 전부 덧셈

        #print(time_term, deadline)
        if time_term / 28 >= deadline: #계약기간보다 지난 달 수가 더 많으면 정답 리스트에 해당 계약 번호 추가
            answer.append(i+1)

    return answer

print(solution("2022.05.19", ["A 6", "B 12", "C 3"], ["2021.05.02 A", "2021.07.01 B", "2022.02.19 C", "2022.02.20 C"])) #answer = [1, 3]
print(solution("2020.01.01",	["Z 3", "D 5"],	["2019.01.01 D", "2019.11.15 Z", "2019.08.02 D", "2019.07.01 D", "2018.12.28 Z"])) #answer = [1, 4, 5]
#월 수로 계산하기 보단 일 수로 계산하여 나중에 월 수로 나누어주는 것이 안전(계약 기간과 오늘 날짜 계산이 관건)
# Out:
# [1, 3]
# [1, 4, 5]

# %%
#https://school.programmers.co.kr/learn/courses/30/lessons/12940
#두 수를 입력받아 두 수의 최대공약수와 최소공배수를 반환하는 함수, solution을 완성해 보세요. 
#배열의 맨 앞에 최대공약수, 그다음 최소공배수를 넣어 반환하면 됩니다. 
#예를 들어 두 수 3, 12의 최대공약수는 3, 최소공배수는 12이므로 
#solution(3, 12)는 [3, 12]를 반환해야 합니다.

def findGCD(n, m): #재귀 함수 사용
    if m==0: #나머지가 0이면 구한 앞에 있는 최대공약수를 반환
        return n
    else: return findGCD(m, n%m) #나머지가 0이 아니면 최대공약수 다시 구하기
    #유클리드 호제법에서 착안
    #m 즉, 나머지가 0이 될 때까지 나누는 수를 계속 나누다 나머지를 0으로 하는 수가 최대공약수임

def solution(n, m):
    GCD = findGCD(n, m) #최대공약수 할당
    LCM = n * m // GCD #최대공약수 & 최소공배수 관계 
    answer = [GCD,LCM]
    return answer

print(solution(3, 12)) #answer = [3, 12]
print(solution(2, 5)) #answer = [1, 10]
#전에 한 최대공약수 구하기 알고리즘이 관건, 유클리드 호제법 숙지
# Out:
# [3, 12]
# [1, 10]

# %%
#https://school.programmers.co.kr/learn/courses/30/lessons/12906
#배열 arr가 주어집니다. 
#배열 arr의 각 원소는 숫자 0부터 9까지로 이루어져 있습니다. 
#이때, 배열 arr에서 연속적으로 나타나는 숫자는 하나만 남기고 전부 제거하려고 합니다. 
#단, 제거된 후 남은 수들을 반환할 때는 배열 arr의 원소들의 순서를 유지해야 합니다. 예를 들면,

#arr = [1, 1, 3, 3, 0, 1, 1] 이면 [1, 3, 0, 1] 을 return 합니다.
#arr = [4, 4, 4, 3, 3] 이면 [4, 3] 을 return 합니다.
#배열 arr에서 연속적으로 나타나는 숫자는 제거하고 남은 수들을 return 하는 solution 함수를 완성해 주세요.

def solution(arr):
    answer = [arr[0]]
    for i, number in enumerate(arr[1:]):
        i += 1
        if number == arr[i-1]:
            continue
        else: answer.append(number)
    return answer
    
print(solution([1, 1, 3, 3, 0, 1, 1])) #answer = [1, 3, 0, 1]
print(solution([4, 4, 4, 3, 3])) #answer = [4, 3]
# Out:
# [1, 3, 0, 1]
# [4, 3]
